# %% [markdown]
# Linear regression model for preding salary according to the years of experience

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score,mean_squared_error
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#Loading the dataset
data = pd.read_csv("C:\\Users\\Admin\\Desktop\\Folders\\Datasets\\Salary_Data.csv")
print("\n\nNumber of missing values in dataset \n",data.isnull().sum())


#Handling the missing values
data['Salary'].fillna(data['Salary'].mean(),inplace=True)
print("\n\nNumber of missing values after replacing in dataset\n",data.isna().sum())

#Plotting graph for finding the outliers in the Salary column for Salary dataset
# sns.boxplot(data) 
# plt.xlabel("Different variables")
# plt.ylabel("Values")
# plt.title("Finding outliers in the Salary dataset")
# plt.legend(['Outliers'])
# plt.show()


#Finding the IQR for finding the outliers of the dataset
# q1 = data["Salary"].quantile(.25)
# q3 = data["Salary"].quantile(.75)
# IQR = q3-q1

# l_b = q1 - 1.5 * IQR
# u_b = q3 + 1.5 * IQR


#Finding the outliers in the dataset
# outliers = data['Salary'][(data['Salary'] <= l_b) | (data['Salary'] >= u_b)]
# print("\n\nThe number of outliers in a dataset are \n",outliers)
# print("\n\n")
# mean = data['Salary'].mean()
# std = data['Salary'].std()
# outlier = []
# for i in range(len(data)):
#     out = (data['Salary'][i] - mean)/std
#     if out > 3:
#         outlier.append(data['Salary'][i])
# print("Outliers using Z score method is",outlier)


#Replacing the outliers with the median value
# median_of_the_data = data['Salary'].median()
# for i in range(len(data)):
#     if data['Salary'][i][(data['Salary'][i] <= l_b) | (data['Salary'][i] >= u_b)]:
#         data['Salary'][i] = median_of_the_data
        

#Crossing verifing the replaced outliers
# sns.boxplot(data)
# plt.xlabel("Different variables")
# plt.ylabel("Values")
# plt.title("No outliers in the Salary dataset after replacing")
# plt.legend(['Outliers'])
# plt.show()


#Showing 0 outliers in the dataset
# outliers = data['Salary'][(data['Salary'] <= l_b) | (data['Salary'] >= u_b)]
# print("\n\nThe number of outliers in a dataset are \n",outliers)




#Splitting the dataset
x = data[['YearsExperience']]
y = data[['Salary']]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 7)


# # Transforming the data
# from sklearn.preprocessing import MinMaxScaler

# min_max_scalar = MinMaxScaler().fit(x_test)
# x_norm = min_max_scalar.transform(x)
# print(x_norm)


#Building the model
model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
new_data = np.array([9]).reshape(-1,1)      #The reshape(-1, 1) operation is used to ensure that the array has one column, but the number of rows is automatically determined based on the size of the input data, in this case, just the value 9. The resulting new_data array will be a 2D array with a shape of (1, 1), representing a single data point.
# print("\n\nThe reshaped data is ",new_data)


#Predicting using the Linear Regression model
model.predict(new_data)


#Checking the model whether it is underfitted or overfitted
plt.scatter(x,y,color = 'k')
plt.plot(x_test,y_pred,color = 'green')
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary plot with respect to Years of Experience")
plt.show()


#Validating the test data with the predicted data
# plt.scatter(x_test,y_test,color = 'k')
# plt.scatter(x_test,y_pred,color = 'g')
# plt.xlabel("Years of experience")
# plt.ylabel("Salary")
# plt.title("Validating the test data with the predicted data")
# plt.show()


#Testing the accuracy of the model
# train_accuracy = model.score(x_train, y_train)
# print("\n\nTrain accuracy of the model is ",train_accuracy)

# test_accuracy = model.score(x_test, y_test)
# print("\nTest accuracy of the model is ",test_accuracy)

print('\nR2_score of the model is ',r2_score(y_test,y_pred))
print("\nMean squared error of the model is ",mean_squared_error(y_test,y_pred))
# Out:
# Number of missing values in dataset
#  YearsExperience    0
# Salary             2
# dtype: int64
#
#
# Number of missing values after replacing in dataset
#  YearsExperience    0
# Salary             0
# dtype: int64
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# R2_score of the model is  -14.243067393326772
#
# Mean squared error of the model is  2960346593.6579633

# %% [markdown]
# Linear regression model for preding marks according to hours of study

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


data = pd.read_csv("C:\\Users\\Admin\\Desktop\\Folders\\Datasets\\Stud_marks.csv")

sns.heatmap(data.corr(),annot=True)
plt.show()

x = data[['time_study']]
y = data[['Marks']]


x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=7)

# print(y_test)

model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)
# new_data = np.array([12]).reshape(-1,1)
# new_data = int(input("Enter number of hours you studied : "))


plt.scatter(x,y, color = "blue")
plt.plot(x_test, y_pred, color='red', linewidth=2)
plt.xlabel('Study hour')
plt.ylabel('Marks')
plt.title('Marks scored with respect to hour of study')
plt.show()
#using scatter plot ploting x_test,y_tset and predicated y_pred with blue and red color
# plt.scatter(x_test,y_test, color = "blue")
# plt.scatter(x_test,y_pred, color = "red")
# plt.xlabel('Study hours')
# plt.ylabel('Marks')
# plt.title('Marks scored with respect to hour of study')
# plt.show()

new_data = np.array([9]).reshape(-1,1)
a = model.predict(new_data)
print("\n\nPredicted marks for 9 hours of study is ",a)


print("\n\nR2 score of the model is ",r2_score(y_test,y_pred))
print("MSE of the model is ",mean_squared_error(y_test,y_pred))
# Out:
# Predicted marks for 9 hours of study is  [[52.6338859]]
#
#
# R2 score of the model is  0.867056814891106
# MSE of the model is  24.87931674717705
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Calculating SEE marks based on the CIE marks of the student

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

data = pd.read_csv("C:\\Users\\Admin\\Desktop\\Folders\\Datasets\\student_marks.csv")
# data = data.iloc[:,1:4]

#Preprocessing the data
data.bfill(inplace = True)
data.isna().sum()
print(data)


#Exploratory data Analysis
sns.displot(data['Assignment'],bins=5)
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Distribution of the independent variable 'Assignment'")
plt.show()


plt.figure(figsize=(10,6))
plt.subplot(1,3,1)
plt.hist(data['Assignment'],bins=5)
plt.title("Distribution of Assignment")

plt.subplot(1,3,2)
plt.hist(data['Tutorial'],bins=5)
plt.title("Distribution of Tutorials")

plt.subplot(1,3,3)
plt.hist(data['Midterm'],bins=5)
plt.title("Distribution of Mid-Term marks")
plt.show()


# correlation_matrix = data.corr().round(2)
# # annot = True to print the values inside the square
# sns.heatmap(data=correlation_matrix, annot=True)


#Data splitting
x = pd.DataFrame(np.c_[data['Assignment'], data['Tutorial'],data['Midterm']], columns = ['Assignment','Tutorial','Midterm'])
# x = data[['Assignment']]
y = data[['Final']]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=13)

# print(x_train,y_train)
model = LinearRegression()
model.fit(x_train,y_train)

y_pred = model.predict(x_test)
# new_data=np.array([57,34,64]).reshape(-1,3)
ass = int(input("Enter your assignment marks : "))
tut = int(input("Enter your tutorial marks : "))
mid = int(input("Enter your midterm marks : "))

    
    
new_data = np.array([ass,tut,mid]).reshape(-1,3)
a = model.predict(new_data)
print("The predicted final marks is ",a)


plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.scatter(x['Assignment'],y,color='k')
plt.plot(x_test['Assignment'],y_pred,color = 'red')
plt.title("Modle training level")


plt.subplot(1,2,2)
plt.scatter(x_test['Assignment'],y_test,color='k')
plt.scatter(x_test['Assignment'],y_pred,color='red')
plt.title("Model predicted with respect to Actural prediction")
plt.show()

# plt.scatter(x_test['Assignment'],y_test,color='k')
# plt.scatter(x_test['Assignment'],y_pred,color='red')
# plt.title("Model predicted with respect to Actural prediction")
# plt.show()

# print("Root mean square error is ",mean_squared_error(y_test,y_pred))
print("R2 is ",r2_score(y_test,y_pred))
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     99.81  87.78
# 97       7       95.60     97.37    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# Boston house pricing

# %%
import pandas as p
import seaborn as s
import matplotlib.pyplot as m

da=p.read_csv("C:\\Users\\Admin\\Desktop\\Folders\\Datasets\\boston.csv")
da.info()
da.ffill(inplace=True)
# print(da.describe())

m.figure(figsize=(12,8))
s.heatmap(data=da.corr(),annot=True,cmap='coolwarm')
m.show()

# m.figure(figsize=(18,10))
s.histplot(data=da,x='MEDV',bins=30,kde=True)
m.title('Distribution of Pricing')
m.show()

# m.figure(figsize=(18,10))
s.scatterplot(data=da,x='RM',y='MEDV',color='k')
m.title('Number of rooms to pricing')
m.show()

# m.figure(figsize=(18,10))
s.scatterplot(data=da,x='LSTAT',y='MEDV',color='k')
m.title('Lower status Population and Pricing')
m.show()

# # ULTRA_LEGENDS_PRO_MAX can uncomment this and understand the graph
# m.figure(figsize=(18,10))
# s.pairplot(data=da,hue=da['MEDV'])
# m.show()





import numpy as n
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

X = da.drop('MEDV', axis=1)  
y = da['MEDV']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Train set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print()

rmse = n.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Checking for the null values in the dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     505 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB
# None
#
#
# Number of null values in the dataset
# CRIM       0
# ZN         0
# INDUS      0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# ...

# %% [markdown]
# Cricket match

# %% [markdown]
# a Pre processing

# %%
import pandas as p
da=p.read_csv("C:\\Users\\Admin\\Desktop\\Folders\\Datasets\\matches.csv")
# da.info()

#PRE_PROCESSING
print("Missing Values before: \n",da.isna().sum())


da.drop('umpire3', axis=1, inplace=True)
da.dropna(axis=0,inplace=True)
# da.drop('date',axis=1,inplace=True)

print("\nMissing Values after:\n",da.isna().sum())
# Out:
# Missing Values before:
#  id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64
#
# Missing Values after:
#  id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
# b Exploration

# %%
import matplotlib.pyplot as m
import seaborn as s

# Function to create a histogram
def histo(da, col, title, xlabel):
    m.figure(figsize=(8, 6))
    s.histplot(da[col], bins=20, kde=True)
    m.title(title)
    m.xlabel(xlabel)
    m.ylabel('Frequency')
    m.show()

# Function to create a count plot
def count_plo(da, x, title, xlabel):
    m.figure(figsize=(15, 7))
    s.countplot(x=x, data=da, palette='Set2')
    m.title(title)
    m.xlabel(xlabel)
    m.ylabel('Count')
    m.xticks(rotation=90)
    m.tight_layout()
    m.show()

# Function to create a stacked bar chart
def sta_bar(da, x, y, title, xlabel, ylabel, legend_title=None):
    dp = da.groupby([x, y]).size().unstack()
    dp.plot(kind='bar', stacked=True, figsize=(10, 6))
    m.title(title)
    m.xlabel(xlabel)
    m.ylabel(ylabel)
    if legend_title:
        m.legend(title=legend_title)
    m.show()

#DATA_EXPLORATION
histo(da, 'win_by_runs', 'Distribution of Win by Runs', 'Win by Runs')
histo(da, 'win_by_wickets', 'Distribution of Win by Wickets', 'Win by Wickets')
count_plo(da, 'venue', 'Count of Matches at Each Venue', 'Venue')
count_plo(da, 'city', 'Count of Matches at Each City', 'City')
count_plo(da, 'winner', 'Count of Winning of Each Team', 'Team')
sta_bar(da, 'toss_decision', 'result', 'Toss Decision vs. Match Result', 'Toss Decision', 'Count', legend_title='Match Result')
sta_bar(da, 'season', 'toss_decision', 'Season-wise Toss Decision', 'Season', 'Count', legend_title='Toss Decision')

pr =da.pivot_table(index='venue', columns='winner', values='id', aggfunc='count', fill_value=0)
m.figure(figsize=(12, 8))
s.heatmap(pr, cmap='coolwarm', annot=True, fmt='d', cbar=True, linewidths=0.5)
m.title('Number of Wins by Each Team at Each Venue')
m.xlabel('Teams')
m.ylabel('Venues')
m.xticks(rotation=90) 
m.show()

# %% [markdown]
# c Splitting

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#Transformation
categorical_columns = ['city', 'team1', 'team2', 'toss_winner', 'toss_decision', 'result', 'player_of_match', 'venue', 'umpire1', 'umpire2','winner','date']
label_encoders = {}

for column in categorical_columns:
    label_encoders[column] = LabelEncoder()
    # print(label_encoders[column])
    da[column] = label_encoders[column].fit_transform(da[column])

X = da.drop('winner', axis=1)  
y = da['winner']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Train set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)
# Out:
# Train set: (437, 16) (437,)
# Test set: (188, 16) (188,)

# %% [markdown]
# Performance of a cricket player

# %% [markdown]
# Preprocessing

# %%
import pandas as p
da=p.read_csv("C:\\Users\\Admin\\Desktop\\Folders\\Datasets\\Ms_Dhoni.csv")
# da.info()

#PRE_PROCESSING
print("\nMissing Values before:\n",da.isna().sum())
da.dropna(inplace=True)
print("\nMissing Values after:\n",da.isna().sum())
# Out:
# Missing Values before:
#  Year             1
# Matches          1
# Innings          1
# N.O.             1
# Runs             1
# Highest Score    1
# Average          1
# Strike Rate      1
# 100              1
# 50               1
# Fours            1
# Sixes            1
# Catches Taken    1
# Stumpings        1
# dtype: int64
#
# Missing Values after:
#  Year             0
# Matches          0
# Innings          0
# N.O.             0
# Runs             0
# Highest Score    0
# Average          0
# Strike Rate      0
# 100              0
# 50               0
# Fours            0
# Sixes            0
# Catches Taken    0
# Stumpings        0
# dtype: int64

# %% [markdown]
# b Exploration

# %%
import matplotlib.pyplot as m
import seaborn as s

# m.figure(figsize=(18,10))
s.histplot(da['Runs'], bins=8, kde=True)
m.title('Distribution of Runs Scored')
m.show()

m.figure(figsize=(18,10))
s.barplot(data=da,x='Year',y='Runs',palette='viridis')
m.title('Batting Scores Over the Years')
m.xlabel('Year');m.ylabel('Runs')
m.xticks(rotation=45)
m.show()

m.figure(figsize=(18,10))
data=da.drop('100',axis=1)
s.heatmap(data=data.corr(),annot=True,cmap='crest',vmin=-1,vmax=1)
m.title("Heatmap on DHONI's stats")
m.show()

# %% [markdown]
# c Splitting

# %%
from sklearn.model_selection import train_test_split

X = da.drop(['Average','Year','Highest Score','Strike Rate','50','100','Fours','Sixes','Catches Taken','Stumpings'], axis=1)  
y = da['Average']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Train set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)
# Out:
# Train set: (10, 4) (10,)
# Test set: (5, 4) (5,)

# %% [markdown]
# Crop Yield

# %% [markdown]
# a Preprocessing

# %%
import pandas as p
da=p.read_csv("C:\\Users\\Admin\\Desktop\\Folders\\Datasets\\crop_production.csv")
# da.info()

#PRE_PROCESSING
print("\nMissing Values before:\n",da.isna().sum())
da.dropna(inplace=True)
print("\nMissing Values after:\n",da.isna().sum())
# Out:
# Missing Values before:
#  State_Name          0
# District_Name       0
# Crop_Year           0
# Season              0
# Crop                0
# Area                0
# Production       3730
# dtype: int64
#
# Missing Values after:
#  State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %% [markdown]
# b Exploration

# %%
import matplotlib.pyplot as m
import seaborn as s

m.figure(figsize=(18,10))
s.countplot(data=da, x='State_Name')
m.title("Sates Which grow Crops")
m.xticks(rotation=90)
m.show()

m.figure(figsize=(18,10))
s.countplot(data=da,x='Crop_Year')
m.title('Crops Grown In an year')
m.xticks(rotation=90)
m.show()

m.figure(figsize=(12, 6))
s.barplot(x=da['Crop_Year'], y=da['Production'],data=da)
m.title('Rice Production by Year')
m.xlabel('Year')
m.ylabel('Production (Metric Tons)')
m.xticks(rotation=45)
m.tight_layout()
m.show()

sn=da.select_dtypes(exclude=['object'])
s.heatmap(data=sn.corr(),annot=True,cmap='coolwarm')
m.show()

# %% [markdown]
# c Splitting

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

#Transformation
categorical_columns = ['State_Name','District_Name','Season','Crop']
label_encoders = {}

for column in categorical_columns:
    label_encoders[column] = LabelEncoder()
    da[column] = label_encoders[column].fit_transform(da[column])

X = da.drop('Production', axis=1)  
y = da['Production']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Train set:", X_train.shape, y_train.shape)
print("Test set:", X_test.shape, y_test.shape)
# Out:
# Train set: (169652, 6) (169652,)
# Test set: (72709, 6) (72709,)
